# %%
import sys

sys.path.append('../src')

# %%
from domain.db import Base, engine


print(f"Engine: {engine}")
# Out:
# Engine: Engine(postgresql://avnadmin:***@accesdades-defaultbd.i.aivencloud.com:16099/defaultdb?sslmode=require)

# %%
# Test físic per la connexió a Aiven
with engine.connect() as connection:
    print("Connexió física amb la base de dades establerta correctament!")
# Out:
# Connexió física amb la base de dades establerta correctament!
