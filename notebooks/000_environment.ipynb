# %%
import sys

sys.path.append('../src')

# %%
import os
from dotenv import load_dotenv
load_dotenv("../.env")
print(f"Variable trobada: {os.getenv('DB_URL_DEVELOPMENT') is not None}")
# Out:
# Variable trobada: True

# %%
from domain import ENVIRONMENT,DATABASE_URL 

(ENVIRONMENT,DATABASE_URL)
# Out:
# ('development',
#  'postgresql://avnadmin:AVNS__UdgrwKbpKijC7XlyXh@accesdades-defaultbd.i.aivencloud.com:16099/defaultdb?sslmode=require')
