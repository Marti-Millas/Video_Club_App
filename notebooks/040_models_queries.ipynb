# %%
import sys

sys.path.append('../src')

# %%
from domain.db import Session
from domain.models import Game, Platform
session = Session()

# %%
# Demostrem que un joc sap la seva plataforma (1:N)
jocs = session.query(Game).all()
for j in jocs:
    print(f"Joc: {j.title} | Plataforma: {j.platform.name}")
session.close()
# Out:
# Joc: Elden Ring | Plataforma: PC
# Joc: Mario Kart 8 | Plataforma: Nintendo Switch
