# %%
import sys

sys.path.append('../src')

# %%
from domain.models import Platform, Game, UserAccount, Tag, Review, UserProfile
from domain.db import engine
from sqlalchemy import inspect

# %%
# Això llista les columnes per demostrar al profe que la migració d'Alembic ha funcionat
inspector = inspect(engine)
columns = inspector.get_columns('game')
print("Columnes de la taula 'game':")
for col in columns:
    print(f"-> {col['name']} ({col['type']})")
# Out:
# Columnes de la taula 'game':
# -> id (INTEGER)
# -> title (VARCHAR(100))
# -> summary (TEXT)
# -> price (NUMERIC(10, 2))
# -> release_year (INTEGER)
# -> platform_id (INTEGER)
# -> last_update (TIMESTAMP)
